# %%
import pandas as pd

# %%
## df = pd.read_csv("spotify_millsongdata.csv")
df_tracks = pd.read_csv("user_top_tracks.csv")
df_artists = pd.read_csv("user_top_artists.csv")
df_albums = pd.read_csv("user_top_albums.csv")

df_tracks.head()
# Out:
#    user_id  rank               track_name          artist_name  playcount  \
# 0        1     1                Ice Cream  New Young Pony Club         54
# 1        1     2  Hiding On The Staircase  New Young Pony Club         51
# 2        1     3                  Descend  New Young Pony Club         49
# 3        1     4                  Air War      Crystal Castles         48
# 4        1     5                Get Lucky  New Young Pony Club         48
#
#                                    mbid
# 0  417a3d0b-0291-4e08-b167-50971dbdae36
# 1  f6ac2fd2-b33b-48ff-a094-537cf530cf20
# 2  33434fd1-79a1-3882-bb31-fbd430815a93
# 3  06d3fea3-e806-35ed-9562-aa396a97de14
# 4  ab351b25-7126-3792-9b0d-ce44fd0c0462

# %%
df_tracks.tail()
# Out:
#           user_id  rank       track_name        artist_name  playcount  \
# 23822545   479484    46            teeth              Loser        192
# 23822546   479484    47       MISA MISA!             Corpse        191
# 23822547   479484    48      title track  Machine Gun Kelly        191
# 23822548   479484    49  В последний раз   Tima Belorusskih        190
# 23822549   479484    50        fantasize            ericdoa        189
#
#                                           mbid
# 23822545                                   NaN
# 23822546                                   NaN
# 23822547  b9874074-b2d6-4135-bc2a-f4ef44b0ae69
# 23822548                                   NaN
# 23822549                                   NaN

# %%
def top_N_songs(user, N):
    return df_tracks.loc[df_tracks["user_id"] == user]["track_name"].tolist()[0:N], df_tracks.loc[df_tracks["user_id"] == user]["artist_name"].tolist()[0:N]

def top_N_artists(user, N):
    return df_artists.loc[df_artists["user_id"] == user]["artist_name"].tolist()[0:N]

def top_N_albums(user, N):
    return df_albums.loc[df_albums["user_id"] == user]["album_name"].tolist()[0:N], df_albums.loc[df_albums["user_id"] == user]["artist_name"].tolist()[0:N]

print(top_N_artists(50, 10))
# Out:
# ['Modest Mouse', 'Wintersleep', 'Wolf Parade', 'Pavement', 'Pixies', 'Eels', 'The Weakerthans', 'TV on the Radio', 'Radiohead', 'Stars']

# %%
def shared_songs(user1, user2):
    song_list, artist_list = [], []
    user1_songs, user2_songs = top_N_songs(user1, 50)[0], top_N_songs(user2, 50)[0]
    user1_artists, user2_artists = top_N_songs(user1, 50)[1], top_N_songs(user2, 50)[1]
    for i in range(50):
        song, artist = user1_songs[i], user1_artists[i]
        if song in user2_songs:
            song_list.append(song)
            artist_list.append(artist)
    return song_list, artist_list

def shared_artists(user1, user2):
    artist_list = []
    user1_artists, user2_artists = top_N_artists(user1, 50), top_N_artists(user2, 50)
    for artist in user1_artists:
        if artist in user2_artists:
            artist_list.append(artist)
    return artist_list

def shared_albums(user1, user2):
    album_list, artist_list = [], []
    user1_albums, user2_albums = top_N_albums(user1, 50)[0], top_N_albums(user2, 50)[0]
    user1_artists, user2_artists = top_N_albums(user1, 50)[1], top_N_albums(user2, 50)[1]
    for i in range(50):
        album, artist = user1_albums[i], user1_artists[i]
        if album in user2_albums:
            album_list.append(album)
            artist_list.append(artist)
    return album_list, artist_list

def artist_songs(artist):
    songs_by_artist = df_tracks.loc[df_tracks["artist_name"] == artist, "track_name"].tolist()
    rand_songs = random.sample(songs_by_artist, 3)
    return rand_songs

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def similarity_to_songs(user, songs):
    songs_list = " ".join(songs)
    user_songs = " ".join(top_N_songs(user, 10)[0])

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([user_songs, songs_list])
    
    return cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]

def user_similarity(user1, user2):
    songs_list = " ".join(top_N_songs(user1, 10)[0])
    user_songs = " ".join(top_N_songs(user2, 10)[0])

    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([user_songs, songs_list])
    
    return cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])[0][0]

print(user_similarity(67, 94))
# Out:
# 0.1362360288173473

# %%
# Install these:
# pip install youtube-search   (simple querying library)
# pip install jupyter          (if not installed already)

# !pip install gradio

from youtube_search import YoutubeSearch
from IPython.display import YouTubeVideo, display
import gradio as gr

# Search YouTube
results = YoutubeSearch("Empire Ants Gorillaz", max_results=1).to_dict()
video_id = results[0]["id"]

# Display inside Jupyter
display(YouTubeVideo(video_id, width=400, height=300))
# Out:
# Requirement already satisfied: gradio in .\anaconda3\Lib\site-packages (6.0.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in .\anaconda3\Lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in .\anaconda3\Lib\site-packages (from gradio) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in .\anaconda3\Lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in .\anaconda3\Lib\site-packages (from gradio) (0.123.5)
# Requirement already satisfied: ffmpy in .\anaconda3\Lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.1 in .\anaconda3\Lib\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: groovy~=0.1 in .\anaconda3\Lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in .\anaconda3\Lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in .\anaconda3\Lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in .\anaconda3\Lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in .\anaconda3\Lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in .\anaconda3\Lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in .\anaconda3\Lib\site-packages (from gradio) (3.11.4)
# Requirement already satisfied: packaging in .\anaconda3\Lib\site-packages (from gradio) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in .\anaconda3\Lib\site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in .\anaconda3\Lib\site-packages (from gradio) (12.1.1)
# Requirement already satisfied: pydantic<=2.12.4,>=2.11.10 in .\anaconda3\Lib\site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub in .\anaconda3\Lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in .\anaconda3\Lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in .\anaconda3\Lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in .\anaconda3\Lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in .\anaconda3\Lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in .\anaconda3\Lib\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in .\anaconda3\Lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in .\anaconda3\Lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in .\anaconda3\Lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in .\anaconda3\Lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in .\anaconda3\Lib\site-packages (from gradio-client==2.0.1->gradio) (2024.3.1)
# Requirement already satisfied: idna>=2.8 in .\anaconda3\Lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\anaconda3\Lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in .\anaconda3\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in .\anaconda3\Lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in .\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in .\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.1)
# Requirement already satisfied: requests in .\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in .\anaconda3\Lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\anaconda3\Lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\anaconda3\Lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in .\anaconda3\Lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in .\anaconda3\Lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\anaconda3\Lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\anaconda3\Lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in .\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in .\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in .\anaconda3\Lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: colorama in .\anaconda3\Lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in .\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in .\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in .\anaconda3\Lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\anaconda3\Lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\anaconda3\Lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.2.2)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random

user_ids = df_tracks["user_id"].unique().tolist()

def song_recommender(songs, N = 5):
    temp = []
    users = []
    extras = []
    show_songs(songs)
    for song in songs:
        if(" | " in song):
            parts = song.split(" | ", 1)
            users += df_tracks.loc[(df_tracks["track_name"].str.lower() == parts[0].lower()) & (df_tracks["artist_name"].str.lower() == parts[1].lower()), "user_id"].tolist()
            extras.append(parts[0])
        else:
            users += df_tracks.loc[df_tracks["track_name"].str.lower() == song.lower(), "user_id"].tolist()
    while(len(temp) < N):
        rand = random.sample(users, 2)
        r1, r2 = rand[0], rand[1]
        if(user_similarity(r1, r2) > 0.05):
            rand_songs = shared_songs(r1, r2)
            if(len(rand_songs[0]) == 0):
                continue
            rand = random.randint(0, len(rand_songs[0]) - 1)
            rand_song = rand_songs[0][rand]
            rand_artist = rand_songs[1][rand]
            if(rand_song not in [song[0] for song in temp] and rand_song.lower() not in [item.lower() for item in songs] and rand_song.lower() not in [item.lower() for item in extras]):
                temp.append([rand_song, rand_artist])
    show_songs(temp)

def artist_recommender(artists, N):
    temp = []
    users = []
    for artist in artists:
        users += df_artists.loc[df_artists["artist_name"].str.lower() == artist.lower(), "user_id"].tolist()
    while(len(temp) < N):
        rand = random.sample(users, 2)
        r1, r2 = rand[0], rand[1]
        rand_artists = shared_artists(r1, r2)
        if(len(rand_artists) == 0):
            continue
        rand_artist = random.sample(rand_artists, 1)[0]
        if(rand_artist not in temp and rand_artist.lower() not in [item.lower() for item in artists]):
            temp.append(rand_artist)
    for artist in temp:
        string = "\"" + artist + "\" with songs: "
        string += "; ".join(artist_songs(artist))
        print(string)
    print("\n")

def album_recommender(albums, N):
    temp = []
    users = []
    for album in albums:
        users += df_albums.loc[df_albums["album_name"].str.lower() == album.lower(), "user_id"].tolist()
    while(len(temp) < N):
        rand = random.sample(users, 2)
        r1, r2 = rand[0], rand[1]
        rand_albums = shared_albums(r1, r2)
        if(len(rand_albums[0]) == 0):
            continue
        rand = random.randint(0, len(rand_albums[0]) - 1)
        rand_album = rand_albums[0][rand]
        rand_artist = rand_albums[1][rand]
        if(rand_album not in [album[0] for album in temp] and rand_album.lower() not in [item.lower() for item in albums]):
            temp.append([rand_album, rand_artist])
    for album in temp:
        print("\"", album[0], "\" by ", album[1])
    print("\n")

def show_songs(songs):
    for song in songs:
        if(len(song) == 2):
            print("\"", song[0], "\" by ", song[1])
            video_id = YoutubeSearch(song[0] + " " + song[1], max_results=1).to_dict()
            video = YouTubeVideo(video_id[0]["id"], width=400, height=300)
        else:
            print("\"", song, "\"")
            video_id = YoutubeSearch(song, max_results=1).to_dict()
            video = YouTubeVideo(video_id[0]["id"], width=400, height=300)
        display(video)

# %%
def grab_songs(seed_text: str) -> str:
    global last_ui_songs

    # One song per line, strip empty lines
    songs = [line.strip() for line in seed_text.split("\n") if line.strip()]
    last_ui_songs = songs  # store in global so we can use them later

    if not songs:
        return "No songs captured. Please enter at least one song."

    # Nice summary message
    joined = "\n".join(f"- {s}" for s in songs)
    return f"Captured {len(songs)} song(s):\n{joined}"

# %%
with gr.Blocks() as demo:
    gr.Markdown(
        """
        # 🎵 Song Input UI

        Enter the songs you like (one per line), then click **Capture Songs**.  
        After that, you can use the `last_ui_songs` variable in your notebook to feed into `song_recommender`.
        """
    )

    song_box = gr.Textbox(
        lines=6,
        label="Seed songs",
        placeholder="One song per line, e.g.:\nAmerican Pie\nLollipop | Mika"
    )

    capture_button = gr.Button("Capture Songs 🎧")
    status = gr.Textbox(label="Status / Captured Songs", interactive=False)

    capture_button.click(
        fn=grab_songs,
        inputs=song_box,
        outputs=status
    )

# %%
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
song_recommender(last_ui_songs, 5)
# Out:
# " Transdermal Celebration | WEEN "
# " Summer '68 | Pink Floyd "
# " Holiday | Vampire Weekend "
# " 12:51 " by  The Strokes
# " What Deaner Was Talkin' About " by  Ween
# " Joppa Road " by  Ween
# " Oxford Comma " by  Vampire Weekend
# " King of Carrot Flowers Pt. 1 " by  Neutral Milk Hotel

# %%
artist_recommender(["Neutral Milk Hotel", "The Smiths"], 5)
# Out:
# "Radiohead" with songs: Karma Police; How to Disappear Completely; Subterranean Homesick Alien
# "Bring Me the Horizon" with songs: LosT; Follow You; Parasite Eve
# "MF DOOM" with songs: One Beer; Dead Bent; Eucalyptus
# "David Bowie" with songs: Fashion; Oh! You Pretty Things - 2015 Remaster; Life On Mars-
# "Tyler, The Creator" with songs: See You Again (feat. Kali Uchis); Yonkers; ARE WE STILL FRIENDS?

# %%
album_recommender(["Atom Heart Mother", "Quebec"], 5)
# Out:
# " Discovery " by  Daft Punk
# " To Be Kind " by  Swans
# " Toxicity " by  System of a Down
# " Meddle " by  Pink Floyd
# " The Mollusk " by  Ween

# %%
song_recommender(["Meet the Frownies"], 5)
# Out:
# " Meet the Frownies "
# " Space Song " by  Beach House
# " So Hot You're Hurting My Feelings " by  Caroline Polachek
# " Flume " by  Bon Iver
# " Weekend " by  Smith Westerns
# " Drown " by  Cuco
